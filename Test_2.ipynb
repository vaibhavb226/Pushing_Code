# %%
import numpy as np
import pandas as pd
import

# %%
df=pd.read_excel(r"C:\Users\vaibhav263717\OneDrive - EXLService.com (I) Pvt. Ltd\Project_1\Python_Masked_Data\df.xlsx")

# %%
df.head()
# Out:
#          Country  Employee Number             Job Family Job Level  \
# 0  United States             2421  Operations Leadership        E4
# 1  United States             2694     Product Management        M3
# 2  United States             1796   Solution Development        P4
# 3  United States             3359     Account Management        M2
# 4  United States             1780     Account Management        M2
#
#                                   Job Title   LOB   DEPT  COE  Manager ID  \
# 0        Sr. Vice President - TM Onboarding  OVHD  IMPLM  FRI      9008.0
# 1           Manager II - Product Management  TRMG  TSAAS  FRI      2421.0
# 2                 Sr. Solution Developer II  OVHD  IMPLM  LOW       355.0
# 3  Manager - Account Management Specialized  BROK  SPSVC  STU        24.0
# 4  Manager - Account Management Specialized  BROK  SPSVC  STU        24.0
#
#    2nd Level Manager ID
# 0               16957.0
# 1                9008.0
# 2               70143.0
# ...

# %%
df.shape
# Out:
# (5471, 10)

# %%
df.isna().sum()
# Out:
# Country                    0
# Employee Number            0
# Job Family              1268
# Job Level               1252
# Job Title                  0
# LOB                        0
# DEPT                       0
# COE                        0
# Manager ID                 1
# 2nd Level Manager ID      19
# dtype: int64
